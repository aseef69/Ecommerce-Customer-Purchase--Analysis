# %% [markdown]
# # E-Commerce Customer Purchase Analysis

# %% [markdown]
# # Objective:
# # To understand customer purchase behavior, preferences, and trends in an e-commerce setting, enabling better decision-making for targeted marketing and sales strategies.

# %% [markdown]
# # Loading Liabraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading Dataset
ecommerce=pd.read_csv("ecom.csv")
ecommerce
# Out:
#           CID         TID  Gender     Age Group        Purchase Date  \
# 0      943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1      180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2      337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3      180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4      447553  8009390577    Male         18-25  31/05/2022 17:00:32
# ...       ...         ...     ...           ...                  ...
# 54995  295864  5407639888   Other         25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other         18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male         45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female         45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male         25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 0            Electronics              Yes        FESTIVE50
# 1            Electronics              Yes  SEASONALOFFER21
# 2               Clothing              Yes  SEASONALOFFER21
# 3       Sports & Fitness               No              NaN
# 4       Sports & Fitness              Yes         WELCOME5
# ...                  ...              ...              ...
# 54995        Electronics              Yes  SEASONALOFFER21
# 54996        Electronics              Yes  SEASONALOFFER21
# 54997     Home & Kitchen              Yes         NEWYEARS
# 54998  Beauty and Health              Yes  SEASONALOFFER21
# 54999  Beauty and Health              Yes         NEWYEARS
#
#        Discount Amount (INR)  Gross Amount   Net Amount   Purchase Method  \
# 0                      64.30    725.304000   661.004000       Credit Card
# 1                     175.19   4638.991875  4463.801875       Credit Card
# 2                     211.54   1986.372575  1774.832575       Credit Card
# 3                       0.00   5695.612650  5695.612650        Debit Card
# 4                     439.92   2292.651500  1852.731500       Credit Card
# ...                      ...           ...          ...               ...
# 54995                 110.89   2819.907300  2709.017300        Debit Card
# 54996                 488.59   3891.303900  3402.713900  Cash on Delivery
# 54997                 417.63   4094.687500  3677.057500       Credit Card
# 54998                 204.56   3977.473500  3772.913500       Credit Card
# 54999                 380.81   3703.581900  3322.771900       Credit Card
#
#         Location
# 0      Ahmedabad
# 1      Bangalore
# 2          Delhi
# 3          Delhi
# 4          Delhi
# ...          ...
# 54995      Other
# 54996  Bangalore
# 54997     Mumbai
# 54998    Kolkata
# 54999     Mumbai
#
# [55000 rows x 13 columns]

# %%
#Exploratory Data Analysis and Cleaning
ecommerce.isnull().sum()
# Out:
# CID                          0
# TID                          0
# Gender                       0
# Age Group                    0
# Purchase Date                0
# Product Category             0
# Discount Availed             0
# Discount Name            27585
# Discount Amount (INR)        0
# Gross Amount                 0
# Net Amount                   0
# Purchase Method              0
# Location                     0
# dtype: int64

# %%
ecommerce.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 54995    False
# 54996    False
# 54997    False
# 54998    False
# 54999    False
# Length: 55000, dtype: bool

# %%
ecommerce.describe()
# Out:
#                  CID           TID  Discount Amount (INR)  Gross Amount  \
# count   55000.000000  5.500000e+04           55000.000000  55000.000000
# mean   551245.593891  5.504740e+09             136.986796   3012.936606
# std    260603.330337  2.594534e+09             165.375502   1718.431066
# min    100009.000000  1.000163e+09               0.000000    136.454325
# 25%    323717.000000  3.252604e+09               0.000000   1562.111325
# 50%    550088.500000  5.498383e+09               0.000000   2954.266150
# 75%    776955.750000  7.747933e+09             274.115000   4342.221675
# max    999996.000000  9.999393e+09             500.000000   8394.825600
#
#          Net Amount
# count  55000.000000
# mean    2875.949810
# std     1726.127778
# min     -351.119775
# 25%     1429.551863
# 50%     2814.910875
# 75%     4211.407838
# max     8394.825600

# %%
ecommerce.shape
# Out:
# (55000, 13)

# %%
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CID                    55000 non-null  int64
#  1   TID                    55000 non-null  int64
#  2   Gender                 55000 non-null  object
#  3   Age Group              55000 non-null  object
#  4   Purchase Date          55000 non-null  object
#  5   Product Category       55000 non-null  object
#  6   Discount Availed       55000 non-null  object
#  7   Discount Name          27415 non-null  object
#  8   Discount Amount (INR)  55000 non-null  float64
#  9   Gross Amount           55000 non-null  float64
#  10  Net Amount             55000 non-null  float64
#  11  Purchase Method        55000 non-null  object
#  12  Location               55000 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 5.5+ MB

# %%
print("select specific column:")
print(ecommerce[["CID","location"]])
# Out:
# select specific column:
#           CID   Location
# 0      943146  Ahmedabad
# 1      180079  Bangalore
# 2      337580      Delhi
# 3      180333      Delhi
# 4      447553      Delhi
# ...       ...        ...
# 54995  295864      Other
# 54996  706435  Bangalore
# 54997  649435     Mumbai
# 54998  982183    Kolkata
# 54999  126691     Mumbai
#
# [55000 rows x 2 columns]

# %%
ecommerce.groupby('location')['CID'].count()
# Out:
# Location
# Ahmedabad     2785
# Bangalore     8249
# Chennai       4368
# Dehradun       553
# Delhi        10799
# Hyderabad     5545
# Jaipur        1678
# Kolkata       2709
# Lucknow       1136
# Mumbai       11197
# Other         1046
# Pune          3781
# Srinagar       548
# Varanasi       606
# Name: CID, dtype: int64

# %%
ecommerce.tail()
# Out:
#           CID         TID  Gender Age Group        Purchase Date  \
# 54995  295864  5407639888   Other     25-45  23/02/2020 10:42:04
# 54996  706435  1144029904   Other     18-25  12/07/2021 15:59:21
# 54997  649435  9587323189    Male     45-60  02/08/2024 09:30:44
# 54998  982183  5032564481  Female     45-60  05/08/2020 23:57:56
# 54999  126691  9172953722    Male     25-45  21/07/2022 09:05:18
#
#         Product Category Discount Availed    Discount Name  \
# 54995        Electronics              Yes  SEASONALOFFER21
# 54996        Electronics              Yes  SEASONALOFFER21
# 54997     Home & Kitchen              Yes         NEWYEARS
# 54998  Beauty and Health              Yes  SEASONALOFFER21
# 54999  Beauty and Health              Yes         NEWYEARS
#
#        Discount Amount (INR)  Gross Amount  Net Amount   Purchase Method  \
# 54995                 110.89     2819.9073   2709.0173        Debit Card
# 54996                 488.59     3891.3039   3402.7139  Cash on Delivery
# 54997                 417.63     4094.6875   3677.0575       Credit Card
# 54998                 204.56     3977.4735   3772.9135       Credit Card
# 54999                 380.81     3703.5819   3322.7719       Credit Card
#
#         Location
# 54995      Other
# 54996  Bangalore
# 54997     Mumbai
# 54998    Kolkata
# 54999     Mumbai

# %%
ecommerce.head()
# Out:
#       CID         TID  Gender     Age Group        Purchase Date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    Product Category Discount Availed    Discount Name  Discount Amount (INR)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    Gross Amount   Net Amount Purchase Method   Location
# 0    725.304000   661.004000     Credit Card  Ahmedabad
# 1   4638.991875  4463.801875     Credit Card  Bangalore
# 2   1986.372575  1774.832575     Credit Card      Delhi
# 3   5695.612650  5695.612650      Debit Card      Delhi
# 4   2292.651500  1852.731500     Credit Card      Delhi

# %%
ecommerce.iloc[:51]
# Out:
#        CID         TID  Gender     Age Group        Purchase Date  \
# 0   943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1   180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2   337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3   180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4   447553  8009390577    Male         18-25  31/05/2022 17:00:32
# 5   200614  3994452858    Male         18-25  12/07/2021 15:10:27
# 6   668787  9460023916    Male         25-45  08/10/2023 16:59:52
# 7   933551  6877673032  Female         18-25  14/12/2022 20:13:45
# 8   414167  2841266620    Male         18-25  29/04/2020 09:10:46
# 9   889269  1342270638   Other  60 and above  18/12/2023 19:04:02
# 10  931578  5168806107   Other         25-45  09/12/2022 19:54:47
# 11  629298  2229511931   Other         45-60  02/11/2021 15:37:38
# 12  665042  3754858574  Female         25-45  23/09/2020 02:22:00
# 13  570860  6791123870    Male         25-45  15/02/2020 05:51:55
# 14  367541  9916932604   Other         18-25  26/09/2021 06:13:58
# 15  143460  2441027824   Other         25-45  15/07/2022 09:26:34
# 16  573298  5515725036   Other         25-45  27/05/2023 19:38:50
# 17  454101  6091881739    Male      under 18  12/04/2020 20:37:09
# 18  337178  6774128207   Other         18-25  20/02/2021 00:10:11
# 19  787512  9582806381    Male         18-25  17/03/2021 17:32:46
# 20  538174  1322344974    Male  60 and above  24/11/2020 02:42:48
# 21  110195  8013666930  Female         25-45  14/02/2022 16:58:48
# 22  443120  4473452038  Female      under 18  07/09/2023 23:23:03
# 23  910099  7930280777   Other         25-45  22/02/2024 21:46:22
# 24  745014  9202622469    Male         18-25  04/05/2023 18:06:02
# 25  292237  1250629827   Other         25-45  09/11/2022 16:08:11
# 26  654718  6758404906   Other      under 18  22/07/2023 23:26:04
# 27  772149  2726106260   Other         18-25  29/10/2022 09:55:05
# 28  655550  7463349293  Female         18-25  14/12/2020 23:20:08
# 29  566018  6086235198   Other         18-25  13/06/2020 23:23:02
# 30  336108  2957151067  Female         25-45  12/01/2023 06:38:34
# 31  521139  2736057295  Female         18-25  17/10/2022 00:01:38
# 32  171973  7034831125   Other         25-45  08/12/2019 21:48:51
# 33  427162  6407323241   Other      under 18  14/10/2019 07:26:19
# 34  572298  3046169433    Male         45-60  30/01/2020 13:10:58
# 35  592489  5651462936    Male  60 and above  19/01/2022 04:05:36
# 36  297594  1955554145  Female         45-60  07/12/2022 02:27:42
# 37  862400  6068201504   Other         25-45  23/01/2020 09:04:23
# 38  343390  7493781432   Other         25-45  03/08/2020 06:15:16
# 39  657783  4766466385   Other  60 and above  30/09/2019 03:04:44
# 40  520940  7063849825    Male         45-60  27/04/2024 20:06:46
# 41  338169  3574854627   Other         18-25  11/01/2022 08:51:21
# 42  652388  5725712173   Other         25-45  13/11/2020 16:32:26
# 43  124240  3303385112    Male         45-60  13/10/2019 10:01:00
# 44  850800  7320956570  Female         25-45  23/02/2021 23:36:04
# 45  860652  4092870576    Male         25-45  01/10/2020 14:59:28
# 46  892356  1692940438  Female         18-25  01/09/2021 02:14:39
# 47  189026  1636012605    Male         25-45  16/03/2021 03:26:01
# 48  543555  3388286985   Other         45-60  17/02/2022 13:02:36
# 49  130710  9646503430   Other         25-45  29/01/2022 07:26:45
# 50  970294  7318079236    Male         45-60  14/01/2021 17:32:31
#
#      Product Category Discount Availed    Discount Name  \
# 0         Electronics              Yes        FESTIVE50
# 1         Electronics              Yes  SEASONALOFFER21
# 2            Clothing              Yes  SEASONALOFFER21
# 3    Sports & Fitness               No              NaN
# 4    Sports & Fitness              Yes         WELCOME5
# 5            Clothing              Yes        FESTIVE50
# 6         Electronics               No              NaN
# 7         Electronics               No              NaN
# 8            Pet Care               No              NaN
# 9            Clothing              Yes           SAVE10
# 10           Clothing               No              NaN
# 11        Electronics               No              NaN
# 12        Electronics              Yes  SEASONALOFFER21
# 13        Electronics              Yes        FESTIVE50
# 14     Home & Kitchen              Yes         NEWYEARS
# 15        Electronics               No              NaN
# 16   Sports & Fitness               No              NaN
# 17        Electronics              Yes         NEWYEARS
# 18     Home & Kitchen              Yes  SEASONALOFFER21
# 19              Books               No              NaN
# 20   Sports & Fitness               No              NaN
# 21        Electronics              Yes         WELCOME5
# 22   Sports & Fitness              Yes         NEWYEARS
# 23        Electronics               No              NaN
# 24           Clothing              Yes           SAVE10
# 25  Beauty and Health              Yes        FESTIVE50
# 26  Beauty and Health               No              NaN
# 27           Clothing               No              NaN
# 28  Beauty and Health               No              NaN
# 29     Home & Kitchen               No              NaN
# 30     Home & Kitchen              Yes         NEWYEARS
# 31  Beauty and Health               No              NaN
# 32     Home & Kitchen              Yes  SEASONALOFFER21
# 33  Beauty and Health              Yes  SEASONALOFFER21
# 34        Electronics              Yes         WELCOME5
# 35  Beauty and Health              Yes         WELCOME5
# 36   Sports & Fitness              Yes         NEWYEARS
# 37        Electronics              Yes         NEWYEARS
# 38              Other               No              NaN
# 39        Electronics               No              NaN
# 40              Other              Yes           SAVE10
# 41       Toys & Games               No              NaN
# 42           Clothing               No              NaN
# 43       Toys & Games               No              NaN
# 44        Electronics               No              NaN
# 45              Books               No              NaN
# 46       Toys & Games              Yes         NEWYEARS
# 47     Home & Kitchen               No              NaN
# 48     Home & Kitchen               No              NaN
# 49        Electronics               No              NaN
# 50   Sports & Fitness              Yes           SAVE10
#
#     Discount Amount (INR)  Gross Amount   Net Amount     Purchase Method  \
# 0                   64.30    725.304000   661.004000         Credit Card
# 1                  175.19   4638.991875  4463.801875         Credit Card
# 2                  211.54   1986.372575  1774.832575         Credit Card
# 3                    0.00   5695.612650  5695.612650          Debit Card
# 4                  439.92   2292.651500  1852.731500         Credit Card
# 5                  127.01   3649.397400  3522.387400         Credit Card
# 6                    0.00   5593.935600  5593.935600         PhonePe UPI
# 7                    0.00   1901.796400  1901.796400         Credit Card
# 8                    0.00   3961.671000  3961.671000          Debit Card
# 9                  437.50   1497.350400  1059.850400         Credit Card
# 10                   0.00   7824.165300  7824.165300         Credit Card
# 11                   0.00    988.172900   988.172900      Google Pay UPI
# 12                  97.88   3508.937775  3411.057775         Net Banking
# 13                 269.87    618.109800   348.239800    Cash on Delivery
# 14                 268.70    560.960400   292.260400         Credit Card
# 15                   0.00   4996.110600  4996.110600          Debit Card
# 16                   0.00   2729.748000  2729.748000         Net Banking
# 17                 368.53    457.317000    88.787000         Credit Card
# 18                 375.51   4141.638600  3766.128600         Credit Card
# 19                   0.00   1952.415300  1952.415300           Paytm UPI
# 20                   0.00   5025.711600  5025.711600         Net Banking
# 21                  83.92   3977.359525  3893.439525          Debit Card
# 22                 268.54   1495.204200  1226.664200          Debit Card
# 23                   0.00   1629.301250  1629.301250         Credit Card
# 24                  75.72   3579.912000  3504.192000         Credit Card
# 25                 353.85   1929.656300  1575.806300         Credit Card
# 26                   0.00   5057.996400  5057.996400          Debit Card
# 27                   0.00   2129.576900  2129.576900         Credit Card
# 28                   0.00   1164.842700  1164.842700          Debit Card
# 29                   0.00   2945.224800  2945.224800         Credit Card
# 30                 450.37   4050.777600  3600.407600         Credit Card
# 31                   0.00   3290.555950  3290.555950         Net Banking
# 32                 108.87   6862.828000  6753.958000         Credit Card
# 33                 425.57   3272.687000  2847.117000          Debit Card
# 34                 144.53   1285.407900  1140.877900         Credit Card
# 35                 489.29   4225.118400  3735.828400      Google Pay UPI
# 36                 404.32   1085.558600   681.238600         Credit Card
# 37                 347.01   1968.019200  1621.009200           Paytm UPI
# 38                   0.00   4940.565000  4940.565000         Credit Card
# 39                   0.00   1917.909000  1917.909000          Debit Card
# 40                  50.76   5798.800000  5748.040000         Credit Card
# 41                   0.00   3283.330500  3283.330500         Net Banking
# 42                   0.00   3875.098500  3875.098500         Credit Card
# 43                   0.00   2331.406000  2331.406000         Net Banking
# 44                   0.00   2145.338800  2145.338800    Cash on Delivery
# 45                   0.00   3060.680700  3060.680700  International Card
# 46                 160.18   2834.843550  2674.663550         Credit Card
# 47                   0.00   1393.319400  1393.319400          Debit Card
# 48                   0.00    384.704900   384.704900      Google Pay UPI
# 49                   0.00   4924.209150  4924.209150         Credit Card
# 50                 263.60   1393.009200  1129.409200          Debit Card
#
#      Location
# 0   Ahmedabad
# 1   Bangalore
# 2       Delhi
# 3       Delhi
# 4       Delhi
# 5       Delhi
# 6       Delhi
# 7       Delhi
# 8       Delhi
# 9   Bangalore
# 10      Other
# 11    Chennai
# 12   Dehradun
# 13    Chennai
# 14       Pune
# 15      Delhi
# 16  Ahmedabad
# 17  Hyderabad
# 18  Ahmedabad
# 19     Mumbai
# 20     Mumbai
# 21      Delhi
# 22     Mumbai
# 23     Jaipur
# 24     Mumbai
# 25       Pune
# 26     Mumbai
# 27  Hyderabad
# 28  Bangalore
# 29       Pune
# 30    Lucknow
# 31  Hyderabad
# 32      Delhi
# 33     Mumbai
# 34   Dehradun
# 35    Chennai
# 36    Kolkata
# 37      Delhi
# 38      Delhi
# 39     Mumbai
# 40     Mumbai
# 41  Bangalore
# 42  Bangalore
# 43  Hyderabad
# 44      Delhi
# 45  Ahmedabad
# 46    Kolkata
# 47      Delhi
# 48      Delhi
# 49  Bangalore
# 50  Bangalore

# %%
ecommerce.describe(include = 'object')
# Out:
#         Gender Age Group        Purchase Date Product Category  \
# count    55000     55000                55000            55000
# unique       3         5                54988                9
# top     Female     25-45  04/07/2022 11:45:29      Electronics
# freq     18454     22010                    2            16574
#
#        Discount Availed Discount Name Purchase Method Location
# count             55000         27415           55000    55000
# unique                2             5               8       14
# top                  No      NEWYEARS     Credit Card   Mumbai
# freq              27585          8135           22096    11197

# %%
for col in ecommerce.describe(include = 'object'):
    print(col)
    print(ecommerce[col].unique())
    print('-'*50)
# Out:
# Gender
# ['Female' 'Male' 'Other']
# --------------------------------------------------
# Age Group
# ['25-45' '60 and above' '18-25' '45-60' 'under 18']
# --------------------------------------------------
# Purchase Date
# ['30/08/2023 20:27:08' '23/02/2024 09:33:46' '06/03/2022 09:09:50' ...
#  '02/08/2024 09:30:44' '05/08/2020 23:57:56' '21/07/2022 09:05:18']
# --------------------------------------------------
# Product Category
# ['Electronics' 'Clothing' 'Sports & Fitness' 'Pet Care' 'Home & Kitchen'
#  'Books' 'Beauty and Health' 'Other' 'Toys & Games']
# --------------------------------------------------
# Discount Availed
# ['Yes' 'No']
# --------------------------------------------------
# Discount Name
# ['FESTIVE50' 'SEASONALOFFER21' nan 'WELCOME5' 'SAVE10' 'NEWYEARS']
# --------------------------------------------------
# Purchase Method
# ['Credit Card' 'Debit Card' 'PhonePe UPI' 'Google Pay UPI' 'Net Banking'
#  'Cash on Delivery' 'Paytm UPI' 'International Card']
# --------------------------------------------------
# Location
# ['Ahmedabad' 'Bangalore' 'Delhi' 'Other' 'Chennai' 'Dehradun' 'Pune'
#  'Hyderabad' 'Mumbai' 'Jaipur' 'Lucknow' 'Kolkata' 'Srinagar' 'Varanasi']
# --------------------------------------------------

# %%
ecommerce.columns = ecommerce.columns.str.lower() #converting column names into lower case for better understanding
ecommerce.head()
# Out:
#       cid         tid  gender     age group        purchase date  \
# 0  943146  5876328741  Female         25-45  30/08/2023 20:27:08
# 1  180079  1018503182    Male         25-45  23/02/2024 09:33:46
# 2  337580  3814082218   Other  60 and above  06/03/2022 09:09:50
# 3  180333  1395204173   Other  60 and above  04/11/2020 04:41:57
# 4  447553  8009390577    Male         18-25  31/05/2022 17:00:32
#
#    product category discount availed    discount name  discount amount (inr)  \
# 0       Electronics              Yes        FESTIVE50                  64.30
# 1       Electronics              Yes  SEASONALOFFER21                 175.19
# 2          Clothing              Yes  SEASONALOFFER21                 211.54
# 3  Sports & Fitness               No              NaN                   0.00
# 4  Sports & Fitness              Yes         WELCOME5                 439.92
#
#    gross amount   net amount purchase method   location
# 0    725.304000   661.004000     Credit Card  Ahmedabad
# 1   4638.991875  4463.801875     Credit Card  Bangalore
# 2   1986.372575  1774.832575     Credit Card      Delhi
# 3   5695.612650  5695.612650      Debit Card      Delhi
# 4   2292.651500  1852.731500     Credit Card      Delhi

# %%
ecommerce['purchase date'] = pd.to_datetime(ecommerce['purchase date']) # changing datatype from object into datatime formatt
ecommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55000 entries, 0 to 54999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cid                    55000 non-null  int64
#  1   tid                    55000 non-null  int64
#  2   gender                 55000 non-null  object
#  3   age group              55000 non-null  object
#  4   purchase date          55000 non-null  datetime64[ns]
#  5   product category       55000 non-null  object
#  6   discount availed       55000 non-null  object
#  7   discount name          27415 non-null  object
#  8   discount amount (inr)  55000 non-null  float64
#  9   gross amount           55000 non-null  float64
#  10  net amount             55000 non-null  float64
#  11  purchase method        55000 non-null  object
#  12  location               55000 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(2), object(7)
# memory usage: 5.5+ MB

# %% [markdown]
# # Data Analysis & Visualization

# %%
#What is the age group with the highest purchasing potential?
age_group_purchase_amount = ecommerce.groupby('age group')['net amount'].sum().reset_index()
age_group_purchase_amount = age_group_purchase_amount.sort_values(by = ['net amount'], ascending = False)

plt.figure(figsize=(8,4))

a =  sns . barplot(age_group_purchase_amount, x = 'age group', y = 'net amount')
plt.title('Total Purchasing Potential by Age Group')
plt.xlabel('Age Group ')
plt.ylabel('Net Purchase Amount')

for bar in a.containers:
    a.bar_label(bar, label_type = 'center', padding = 3, color = 'w')    
plt.show()

# %%
#Which gender shows higher purchasing activity? gender and net amount?
gender_purchasing_power = ecommerce.groupby('gender')['net amount'].sum().reset_index()
gender_purchasing_power = gender_purchasing_power.sort_values(by = ['net amount'], ascending = False)

plt.figure(figsize=(8,3))

a = sns.barplot(gender_purchasing_power, x='gender', y='net amount', )
plt.title('Total Purchasing Potential by Gender')
plt.xlabel('Gender')
plt.ylabel('Net Purchase Amount')

for bars in a.containers:
    a.bar_label(bars, label_type = 'center', color = 'w')
    
plt.show()

# %%
#What are the top-selling product categories?
category_sales = ecommerce.groupby('product category')['net amount'].sum().reset_index()
category_sales = category_sales.sort_values(by = ['net amount'], ascending = False)

plt.figure(figsize=(12,4))

a = sns.barplot(category_sales, x='product category', y='net amount', width = 0.8)
plt.title('Total Sales by product category')
plt.xlabel('product category')
plt.xticks(rotation =45)
plt.ylabel('Net Purchase Amount')

for bars in a.containers:
    a.bar_label(bars)

plt.show()

# %%
#Which location generates the most revenue?
Location_sales = ecommerce.groupby('location')['net amount'].sum().reset_index()
Location_sales = Location_sales.sort_values(by = ['net amount'], ascending = False)
Location_sales
# Out:
#      location    net amount
# 9      Mumbai  3.208384e+07
# 4       Delhi  3.109897e+07
# 1   Bangalore  2.361955e+07
# 5   Hyderabad  1.581339e+07
# 2     Chennai  1.263518e+07
# 11       Pune  1.090214e+07
# 0   Ahmedabad  8.114984e+06
# 7     Kolkata  7.805355e+06
# 6      Jaipur  4.854492e+06
# 8     Lucknow  3.270708e+06
# 10      Other  3.079422e+06
# 13   Varanasi  1.744066e+06
# 12   Srinagar  1.585927e+06
# 3    Dehradun  1.569219e+06

# %%
#Which location generates the most revenue?
plt.figure(figsize=(20,4))

a = sns.barplot(Location_sales, x='location', y='net amount')
plt.title('Total Sales by location')
plt.xlabel('location')
plt.ylabel('Net Purchase Amount')

for bars in a.containers:
    a.bar_label(bars)

plt.show()

# %%
#Do discounts impact the purchasing behavior significantly?
discounted_sales = ecommerce.groupby(ecommerce['discount availed']=='Yes')['net amount'].mean().reset_index()
discounted_sales = discounted_sales.sort_values(by = 'net amount', ascending = False)
discounted_sales
# Out:
#    discount availed   net amount
# 0             False  3013.379444
# 1              True  2737.667978

# %%
#Do discounts impact the purchasing behavior significantly?
plt.figure(figsize=(6,4))

a = sns.boxplot(discounted_sales, x='discount availed', y='net amount')
plt.title('Impact of Discounts on Sales')
plt.xlabel('Discount Availed')
plt.ylabel('Net Purchase Amount')

plt.show()

# %%
#Which time of year shows peak sales activity?
monthly_sales = ecommerce.groupby(ecommerce['purchase date'].dt.month)['net amount'].sum().reset_index()
monthly_sales = monthly_sales.sort_values(by = ['purchase date'], ascending = True)
monthly_sales
# Out:
#     purchase date    net amount
# 0               1  1.202647e+07
# 1               2  1.000025e+07
# 2               3  1.255316e+07
# 3               4  1.301843e+07
# 4               5  1.319709e+07
# 5               6  1.132360e+07
# 6               7  1.184880e+07
# 7               8  1.321897e+07
# 8               9  1.321861e+07
# 9              10  1.402244e+07
# 10             11  1.584837e+07
# 11             12  1.790106e+07

# %%
#plot the mouthly sales using a line plot with markers.
monthly_sales = ecommerce.groupby(ecommerce['purchase date'].dt.month)['net amount'].sum().reset_index()
monthly_sales = monthly_sales.sort_values(by = ['purchase date'], ascending = True)

plt.figure(figsize=(12,4))

a = sns.lineplot(monthly_sales, x='purchase date', y='net amount', markers = 'o')
plt.title('Monthly Sales')
plt.xlabel('Months')
plt.ylabel('Net Purchase Amount')

plt.show()

# %% [markdown]
# # What is the most popular purchase method?

# %%
popular_purchase_method = ecommerce['purchase method'].value_counts()
popular_purchase_method
# Out:
# purchase method
# Credit Card           22096
# Debit Card            13809
# Net Banking            5485
# International Card     2815
# Cash on Delivery       2768
# PhonePe UPI            2683
# Paytm UPI              2674
# Google Pay UPI         2670
# Name: count, dtype: int64

# %%
popular_purchase_method = ecommerce['purchase method'].value_counts()

plt.figure(figsize = (8,8))
plt.pie(popular_purchase_method, labels= popular_purchase_method.index, autopct = '%.2f')
plt.title('Distribution of Purchasing Methods')
plt.show()
